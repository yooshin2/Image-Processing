# %% [markdown]
# <a href="https://colab.research.google.com/github/yooshin2/Image-Processing/blob/main/OpenCVPractice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ddc7dbdc-86d0-42f7-98d7-c092e4d48900" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ddc7dbdc-86d0-42f7-98d7-c092e4d48900">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving people1.jpg to people1 (1).jpg
# ...

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('people1.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_GRAY2RGB))
plt.show()

# %%
import cv2

img = cv2.imread('people1.jpg')
print(img.shape)
print(img.size)

px = img[100][100]
print(px)

print(px[2])
# Out:
# (479, 720, 3)
# 1034640
# [229 222 213]
# 213

# %%
import cv2
import matplotlib.pyplot as plt
import time

image = cv2.imread('people1.jpg')

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i, j] = [255, 255, 255]
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
image[0:100, :100] = [0, 0, 0]
print("--- %s seconds ---" % (time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# --- 0.014224767684936523 seconds ---
# --- 0.0003712177276611328 seconds ---

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('people1.jpg')

roi = image[200:350, 50:200]

image[0:150, 0:150] = roi

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('people1.jpg')
image[:, :, 2] = 0

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
