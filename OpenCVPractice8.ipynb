# %% [markdown]
# <a href="https://colab.research.google.com/github/yooshin2/Image-Processing/blob/main/OpenCVPractice8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40dc1c33-ef61-41a8-a9df-eb214e7b1584" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40dc1c33-ef61-41a8-a9df-eb214e7b1584">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving img_1.jpg to img_1.jpg

# %% [markdown]
# 직접 커널을 생성하여 필터 적용하기

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('img_1.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

size = 4
kernel = np.ones((size, size), np.float32) / (size ** 2)

dst = cv2.filter2D(image, -1, kernel)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Basic Blur

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('img_1.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

dst = cv2.blur(image, (4, 4))
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Gaussian Blur

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('img_1.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# kernel_size : 홀수
dst = cv2.GaussianBlur(image, (5, 5), 0)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
